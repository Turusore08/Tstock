# %%
import yfinance as yf
from datetime import date

# %%
today = date.today()

# %%
data = yf.download("BBCA", start=today.replace(year=today.year-1),end=today)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(data)
# Out:
# Price           Close       High        Low       Open  Volume
# Ticker           BBCA       BBCA       BBCA       BBCA    BBCA
# Date
# 2025-01-21  70.968887  70.978692  70.037661  70.076872  159000
# 2025-01-22  70.723831  71.017897  70.694425  70.890469  190600
# 2025-01-23  71.223747  71.282559  70.763036  70.802247  250000
# 2025-01-24  71.390388  71.517816  71.262953  71.360983  144900
# 2025-01-27  71.076714  71.115924  70.625807  70.625807  490900
# ...               ...        ...        ...        ...     ...
# 2026-01-13  94.800003  95.230003  94.620003  95.120003  565500
# 2026-01-14  94.849998  95.029999  94.339996  94.989998  238400
# 2026-01-15  95.110001  95.370003  94.660004  94.660004  190600
# 2026-01-16  94.930000  95.190002  94.580002  95.129997  190700
# 2026-01-20  94.730003  95.279999  94.699997  94.849998   93180
#
# [251 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2025-01-21 to 2026-01-20
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, BBCA)   251 non-null    float64
#  1   (High, BBCA)    251 non-null    float64
#  2   (Low, BBCA)     251 non-null    float64
#  3   (Open, BBCA)    251 non-null    float64
#  4   (Volume, BBCA)  251 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 11.8 KB

# %%
ticker_data = yf.ticker("BBCA")

# %%
print(data_history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(data_history)
#
# NameError: name 'data_history' is not defined
